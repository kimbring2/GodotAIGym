# %%
import os
import random
import gym
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, Lambda, Add, Conv2D, Flatten, LSTM
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import backend as K
import cv2
import threading
from threading import Thread, Lock
import time
import tensorflow_probability as tfp
from typing import Any, List, Sequence, Tuple
from Basic3DPlatformer import Basic3DPlatformer

os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

tfd = tfp.distributions


class OurModel(tf.keras.Model):
    def __init__(self, action_space):
        super(OurModel, self).__init__()

        self.conv_1 = tf.keras.layers.Conv2D(24, 7, 4, padding="valid", activation="relu")
        self.conv_2 = tf.keras.layers.Conv2D(48, 3, 2, padding="valid", activation="relu")
        self.conv_3 = tf.keras.layers.Conv2D(96, 2, 1, padding="valid", activation="relu")
        self.conv_4 = tf.keras.layers.Conv2D(512, 6, 1, padding="valid", activation="relu")
    
        self.lstm = LSTM(128, return_sequences=True, return_state=True)
        
        self.dense_1 = Dense(action_space)
        self.dense_2 = Dense(1)
        
    def call(self, state, memory_state, carry_state):
        batch_size = state.shape[0]

        conv_1 = self.conv_1(state)
        conv_2 = self.conv_2(conv_1)
        conv_3 = self.conv_3(conv_2)
        conv_4 = self.conv_4(conv_3)
    
        conv_4_reshaped = tf.keras.layers.Reshape((8, 64))(conv_4)
        
        initial_state = (memory_state, carry_state)
        lstm_output, final_memory_state, final_carry_state = self.lstm(conv_4_reshaped, initial_state=initial_state)
        lstm_output_flattened = Flatten()(lstm_output)
        
        action_logit = self.dense_1(lstm_output_flattened)
        value = self.dense_2(lstm_output_flattened)
        
        return action_logit, value, final_memory_state, final_carry_state


sparse_ce = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction=tf.keras.losses.Reduction.SUM)
mse_loss = tf.keras.losses.MeanSquaredError()

ACTIONS = {
      'look_left': [-100, 0, 0, 0, 0],
      'look_right': [100, 0, 0, 0, 0],
      'strafe_left': [0, 0, -1, 0, 0],
      'strafe_right': [0, 0, 1, 0, 0],
      'forward': [0, 0, 0, 1, 0],
      'backward': [0, 0, 0, -1, 0]
}


class A3CAgent:
    def __init__(self, env_name):
        self.env_name = env_name
        
        GODOT_BIN_PATH = "basic_3d_platformer/Basic3DPlatformer.x86_64"
        env_abs_path = "basic_3d_platformer/Basic3DPlatformer.pck"
        
        self.env = Basic3DPlatformer(exec_path=GODOT_BIN_PATH, env_path=env_abs_path, turbo_mode=True)
        self.action_size = len(ACTIONS)
        self.EPISODES, self.episode, self.max_average = 2000000, 0, -21.0 # specific for pong
        self.lr = 0.0001

        self.scores, self.episodes, self.average = [], [], []

        self.Save_Path = 'Models'

        if not os.path.exists(self.Save_Path): os.makedirs(self.Save_Path)
        self.path = '{}_A3C_{}'.format(self.env_name, self.lr)
        self.model_name = os.path.join(self.Save_Path, self.path)

        # Create Actor-Critic network model
        self.ActorCritic = OurModel(action_space=self.action_size)
        self.optimizer = tf.keras.optimizers.Adam(self.lr)

        self.writer = tf.summary.create_file_writer("tensorboard")

    def act(self, state, memory_state, carry_state):
        memory_state = tf.constant(memory_state, tf.float32)
        carry_state = tf.constant(carry_state, tf.float32)
        
        prediction = self.ActorCritic(state, memory_state, carry_state, training=False)
        action = tf.random.categorical(prediction[0], 1).numpy()

        memory_state = prediction[2].numpy()
        carry_state = prediction[3].numpy()
        
        return action[0][0], memory_state, carry_state

    def discount_rewards(self, rewards):
        # Compute the gamma-discounted rewards over an episode
        gamma = 0.99    # discount rate
        running_add = 0
        discounted_r = np.zeros_like(rewards)
        for i in reversed(range(0, len(rewards))):
            if rewards[i] != 0: # reset the sum, since this was a game boundary (pong specific!)
                running_add = 0

            running_add = running_add * gamma + rewards[i]
            discounted_r[i] = running_add

        if np.std(discounted_r) != 0.0:
            discounted_r -= np.mean(discounted_r) # normalizing the result
            discounted_r /= np.std(discounted_r) # divide by standard deviation

        return discounted_r

    def replay(self, states, actions, rewards):
        states = np.vstack(states)
        batch_size = states.shape[0]
        
        discounted_r = self.discount_rewards(rewards)
        discounted_r_ = np.vstack(discounted_r)
        with tf.GradientTape() as tape:
            action_logits = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
            values = tf.TensorArray(dtype=tf.float32, size=0, dynamic_size=True)
            
            memory_state = tf.zeros([1,128], dtype=np.float32)
            carry_state = tf.zeros([1,128], dtype=np.float32)
            for i in tf.range(0, batch_size):
                prediction = self.ActorCritic(tf.expand_dims(states[i], 0), memory_state, carry_state, training=True)
                
                action_logits = action_logits.write(i, prediction[0][0])
                values = values.write(i, prediction[1][0])
                
                memory_state = prediction[2]
                carry_state = prediction[3]
                
            action_logits = action_logits.stack()
            values = values.stack()
            
            advantages = discounted_r - np.stack(values)[:, 0] 
            
            action_probs = tf.nn.softmax(action_logits)
            dist = tfd.Categorical(probs=action_probs)
            action_log_prob = dist.prob(actions)
            action_log_prob = tf.math.log(action_log_prob)
            
            actor_loss = -tf.math.reduce_mean(action_log_prob * advantages) 
            
            critic_loss = mse_loss(values, discounted_r_)
            critic_loss = tf.cast(critic_loss, 'float32')
            total_loss = actor_loss + critic_loss
        
        grads = tape.gradient(total_loss, self.ActorCritic.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.ActorCritic.trainable_variables))

    def load(self, model_name):
        self.ActorCritic = load_model(model_name, compile=False)

    def save(self):
        self.ActorCritic.save(self.model_name)

    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores[-50:]) / len(self.scores[-50:]))
        return self.average[-1]

    def reset(self):
        state = self.env.reset()
        state = np.reshape(state, (128, 128, 3))
        state = cv2.resize(state, (64, 64)) / 255.0
        
        return state

    def step(self, action):
        next_state, reward, done, info = self.env.step(action)
        next_state = np.reshape(next_state, (128, 128, 3)) 
        next_state = cv2.resize(next_state, (64, 64)) / 255.0
        
        return next_state, reward[0], done[0], info

    def train(self):
        while self.episode < self.EPISODES:
            # Reset episode
            score, done, SAVING = 0, False, ''
            state = self.reset()
            state = np.expand_dims(state, 0)

            states, actions, rewards = [], [], []
            
            memory_state = np.zeros([1,128], dtype=np.float32)
            carry_state = np.zeros([1,128], dtype=np.float32)
            #while not done:
            for step in range(0, 750):
                action_idx, memory_state, carry_state = agent.act(state, memory_state, carry_state)
                action_key = list(ACTIONS.keys())[action_idx]
                action = ACTIONS[action_key]
                
                next_state, reward, done, _ = self.step(action)
                next_state = np.expand_dims(next_state, 0)

                states.append(state)
                actions.append(action_idx)
                rewards.append(reward)

                score += reward
                state = next_state

            self.replay(states, actions, rewards)
            states, actions, rewards = [], [], []

            average = self.PlotModel(score, self.episode)
            
            if average >= self.max_average:
                self.max_average = average
                #self.save()
                SAVING = "SAVING"
            else:
                SAVING = ""

            print("episode: {}/{}, score: {}, average: {} {}".format(self.episode, self.EPISODES, score, average, SAVING))
            with self.writer.as_default():
                tf.summary.scalar("average_reward", average, step=self.episode)
                self.writer.flush()
            
            if self.episode < self.EPISODES:
                self.episode += 1

        env.close()

    def test(self, Actor_name, Critic_name):
        self.load(Actor_name, Critic_name)
        for e in range(100):
            state = self.reset(self.env)
            done = False
            score = 0
            while not done:
                self.env.render()
                action = np.argmax(self.Actor.predict(state))
                state, reward, done, _ = self.step(action, self.env, state)
                score += reward
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, score))
                    break

        self.env.close()


if __name__ == "__main__":
    env_name = 'PongDeterministic-v4'
    agent = A3CAgent(env_name)
    agent.train()
# Out:
# 2024-09-27 21:50:03.962687: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-27 21:50:03.962721: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-27 21:50:03.962756: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-27 21:50:03.970594: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# _GodotEnv.__file__:  /media/kimbring2/NewHDD/godot_env/lib/python3.9/site-packages/GodotEnv-0.1-py3.9-linux-x86_64.egg/_GodotEnv.cpython-39-x86_64-linux-gnu.so
# Created float32 vector test agent_action_environment0 size = 5
# Created int32 vector env_action_environment0 size = 1
# Created uint32 vector observation_environment0 size = 49152
# Created float32 vector test reward_environment0 size = 1
# Created int32 vector done_environment0 size = 1
# 2024-09-27 21:50:06.887648: E tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2024-09-27 21:50:06.887675: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:168] retrieving CUDA diagnostic information for host: kimbring2-ROG-Strix-GA35DX-G35DX
# 2024-09-27 21:50:06.887681: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:175] hostname: kimbring2-ROG-Strix-GA35DX-G35DX
# 2024-09-27 21:50:06.887732: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:199] libcuda reported version is: 535.183.1
# 2024-09-27 21:50:06.887752: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:203] kernel reported version is: 535.183.1
# 2024-09-27 21:50:06.887756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:309] kernel version seems to match DSO: 535.183.1
# episode: 0/2000000, score: 0.0, average: 0.0 SAVING
# episode: 1/2000000, score: 4.0, average: 2.0 SAVING
# episode: 2/2000000, score: 2.0, average: 2.0 SAVING
# episode: 3/2000000, score: 0.0, average: 1.5
# episode: 4/2000000, score: 3.0, average: 1.8
# episode: 5/2000000, score: 2.0, average: 1.8333333333333333
# episode: 6/2000000, score: 2.0, average: 1.8571428571428572
# episode: 7/2000000, score: 2.0, average: 1.875
# episode: 8/2000000, score: 1.0, average: 1.7777777777777777
# episode: 9/2000000, score: 2.0, average: 1.8
# episode: 10/2000000, score: 1.0, average: 1.7272727272727273
# episode: 11/2000000, score: 3.0, average: 1.8333333333333333
# episode: 12/2000000, score: 2.0, average: 1.8461538461538463
# episode: 13/2000000, score: 2.0, average: 1.8571428571428572
# episode: 14/2000000, score: 2.0, average: 1.8666666666666667
# episode: 15/2000000, score: 2.0, average: 1.875
# episode: 16/2000000, score: 3.0, average: 1.9411764705882353
# episode: 17/2000000, score: 1.0, average: 1.8888888888888888
# episode: 18/2000000, score: 2.0, average: 1.894736842105263
# episode: 19/2000000, score: 2.0, average: 1.9
# episode: 20/2000000, score: 1.0, average: 1.8571428571428572
# episode: 21/2000000, score: 2.0, average: 1.8636363636363635
# episode: 22/2000000, score: 3.0, average: 1.9130434782608696
# episode: 23/2000000, score: 2.0, average: 1.9166666666666667
# episode: 24/2000000, score: 3.0, average: 1.96
# episode: 25/2000000, score: 2.0, average: 1.9615384615384615
# episode: 26/2000000, score: 2.0, average: 1.962962962962963
# episode: 27/2000000, score: 3.0, average: 2.0 SAVING
# episode: 28/2000000, score: 0.0, average: 1.9310344827586208
# episode: 29/2000000, score: 2.0, average: 1.9333333333333333
# episode: 30/2000000, score: 2.0, average: 1.935483870967742
# episode: 31/2000000, score: 1.0, average: 1.90625
# episode: 32/2000000, score: 2.0, average: 1.9090909090909092
# episode: 33/2000000, score: 5.0, average: 2.0 SAVING
# episode: 34/2000000, score: 3.0, average: 2.0285714285714285 SAVING
# episode: 35/2000000, score: 2.0, average: 2.0277777777777777
# episode: 36/2000000, score: 1.0, average: 2.0
# episode: 37/2000000, score: 2.0, average: 2.0
# episode: 38/2000000, score: 2.0, average: 2.0
# episode: 39/2000000, score: 3.0, average: 2.025
# episode: 40/2000000, score: 2.0, average: 2.024390243902439
# episode: 41/2000000, score: 3.0, average: 2.0476190476190474 SAVING
# episode: 42/2000000, score: 1.0, average: 2.0232558139534884
# episode: 43/2000000, score: 1.0, average: 2.0
# episode: 44/2000000, score: 4.0, average: 2.0444444444444443
# episode: 45/2000000, score: 2.0, average: 2.0434782608695654
# episode: 46/2000000, score: 3.0, average: 2.0638297872340425 SAVING
# episode: 47/2000000, score: 3.0, average: 2.0833333333333335 SAVING
# episode: 48/2000000, score: 1.0, average: 2.061224489795918
# episode: 49/2000000, score: 4.0, average: 2.1 SAVING
# episode: 50/2000000, score: 3.0, average: 2.16 SAVING
# episode: 51/2000000, score: 3.0, average: 2.14
# episode: 52/2000000, score: 3.0, average: 2.16 SAVING
# episode: 53/2000000, score: 3.0, average: 2.22 SAVING
# episode: 54/2000000, score: 3.0, average: 2.22 SAVING
# episode: 55/2000000, score: 3.0, average: 2.24 SAVING
# episode: 56/2000000, score: 4.0, average: 2.28 SAVING
# episode: 57/2000000, score: 2.0, average: 2.28 SAVING
# episode: 58/2000000, score: 3.0, average: 2.32 SAVING
# episode: 59/2000000, score: 3.0, average: 2.34 SAVING
# episode: 60/2000000, score: 2.0, average: 2.36 SAVING
# episode: 61/2000000, score: 3.0, average: 2.36 SAVING
# episode: 62/2000000, score: 3.0, average: 2.38 SAVING
# episode: 63/2000000, score: 3.0, average: 2.4 SAVING
# episode: 64/2000000, score: 1.0, average: 2.38
# episode: 65/2000000, score: 1.0, average: 2.36
# episode: 66/2000000, score: 2.0, average: 2.34
# episode: 67/2000000, score: 2.0, average: 2.36
# episode: 68/2000000, score: 3.0, average: 2.38
# episode: 69/2000000, score: 2.0, average: 2.38
# episode: 70/2000000, score: 3.0, average: 2.42 SAVING
# episode: 71/2000000, score: 2.0, average: 2.42 SAVING
# episode: 72/2000000, score: 3.0, average: 2.42 SAVING
# episode: 73/2000000, score: 2.0, average: 2.42 SAVING
# episode: 74/2000000, score: 2.0, average: 2.4
# episode: 75/2000000, score: 2.0, average: 2.4
# episode: 76/2000000, score: 3.0, average: 2.42 SAVING
# episode: 77/2000000, score: 1.0, average: 2.38
# episode: 78/2000000, score: 2.0, average: 2.42 SAVING
# episode: 79/2000000, score: 2.0, average: 2.42 SAVING
# episode: 80/2000000, score: 4.0, average: 2.46 SAVING
# episode: 81/2000000, score: 4.0, average: 2.52 SAVING
# episode: 82/2000000, score: 2.0, average: 2.52 SAVING
# episode: 83/2000000, score: 2.0, average: 2.46
# episode: 84/2000000, score: 3.0, average: 2.46
# episode: 85/2000000, score: 3.0, average: 2.48
# episode: 86/2000000, score: 2.0, average: 2.5
# episode: 87/2000000, score: 3.0, average: 2.52 SAVING
# episode: 88/2000000, score: 3.0, average: 2.54 SAVING
# episode: 89/2000000, score: 2.0, average: 2.52
# episode: 90/2000000, score: 2.0, average: 2.52
# episode: 91/2000000, score: 1.0, average: 2.48
# episode: 92/2000000, score: 2.0, average: 2.5
# episode: 93/2000000, score: 2.0, average: 2.52
# episode: 94/2000000, score: 2.0, average: 2.48
# episode: 95/2000000, score: 2.0, average: 2.48
# episode: 96/2000000, score: 4.0, average: 2.5
# episode: 97/2000000, score: 3.0, average: 2.5
# episode: 98/2000000, score: 3.0, average: 2.54 SAVING
# episode: 99/2000000, score: 2.0, average: 2.5
# episode: 100/2000000, score: 4.0, average: 2.52
# episode: 101/2000000, score: 3.0, average: 2.52
# episode: 102/2000000, score: 3.0, average: 2.52
# episode: 103/2000000, score: 1.0, average: 2.48
# episode: 104/2000000, score: 4.0, average: 2.5
# episode: 105/2000000, score: 4.0, average: 2.52
# episode: 106/2000000, score: 2.0, average: 2.48
# episode: 107/2000000, score: 2.0, average: 2.48
# episode: 108/2000000, score: 3.0, average: 2.48
# episode: 109/2000000, score: 3.0, average: 2.48
# episode: 110/2000000, score: 2.0, average: 2.48
# episode: 111/2000000, score: 2.0, average: 2.46
# episode: 112/2000000, score: 4.0, average: 2.48
# episode: 113/2000000, score: 2.0, average: 2.46
# episode: 114/2000000, score: 2.0, average: 2.48
# episode: 115/2000000, score: 4.0, average: 2.54 SAVING
# episode: 116/2000000, score: 2.0, average: 2.54 SAVING
# episode: 117/2000000, score: 3.0, average: 2.56 SAVING
# episode: 118/2000000, score: 4.0, average: 2.58 SAVING
# episode: 119/2000000, score: 3.0, average: 2.6 SAVING
# episode: 120/2000000, score: 4.0, average: 2.62 SAVING
# episode: 121/2000000, score: 3.0, average: 2.64 SAVING
# episode: 122/2000000, score: 3.0, average: 2.64 SAVING
# episode: 123/2000000, score: 3.0, average: 2.66 SAVING
# episode: 124/2000000, score: 6.0, average: 2.74 SAVING
# episode: 125/2000000, score: 4.0, average: 2.78 SAVING
# episode: 126/2000000, score: 3.0, average: 2.78 SAVING
# episode: 127/2000000, score: 2.0, average: 2.8 SAVING
# episode: 128/2000000, score: 5.0, average: 2.86 SAVING
# episode: 129/2000000, score: 3.0, average: 2.88 SAVING
# episode: 130/2000000, score: 4.0, average: 2.88 SAVING
# episode: 131/2000000, score: 1.0, average: 2.82
# episode: 132/2000000, score: 3.0, average: 2.84
# episode: 133/2000000, score: 1.0, average: 2.82
# episode: 134/2000000, score: 2.0, average: 2.8
# episode: 135/2000000, score: 3.0, average: 2.8
# episode: 136/2000000, score: 9.0, average: 2.94 SAVING
# episode: 137/2000000, score: 3.0, average: 2.94 SAVING
# episode: 138/2000000, score: 3.0, average: 2.94 SAVING
# episode: 139/2000000, score: 4.0, average: 2.98 SAVING
# episode: 140/2000000, score: 5.0, average: 3.04 SAVING
# episode: 141/2000000, score: 4.0, average: 3.1 SAVING
# episode: 142/2000000, score: 2.0, average: 3.1 SAVING
# episode: 143/2000000, score: 6.0, average: 3.18 SAVING
# episode: 144/2000000, score: 5.0, average: 3.24 SAVING
# episode: 145/2000000, score: 4.0, average: 3.28 SAVING
# episode: 146/2000000, score: 2.0, average: 3.24
# episode: 147/2000000, score: 4.0, average: 3.26
# episode: 148/2000000, score: 3.0, average: 3.26
# episode: 149/2000000, score: 4.0, average: 3.3 SAVING
# episode: 150/2000000, score: 5.0, average: 3.32 SAVING
# episode: 151/2000000, score: 4.0, average: 3.34 SAVING
# episode: 152/2000000, score: 4.0, average: 3.36 SAVING
# episode: 153/2000000, score: 6.0, average: 3.46 SAVING
# episode: 154/2000000, score: 3.0, average: 3.44
# episode: 155/2000000, score: 5.0, average: 3.46 SAVING
# episode: 156/2000000, score: 4.0, average: 3.5 SAVING
# episode: 157/2000000, score: 4.0, average: 3.54 SAVING
# episode: 158/2000000, score: 3.0, average: 3.54 SAVING
# episode: 159/2000000, score: 3.0, average: 3.54 SAVING
# episode: 160/2000000, score: 5.0, average: 3.6 SAVING
# episode: 161/2000000, score: 4.0, average: 3.64 SAVING
# episode: 162/2000000, score: 7.0, average: 3.7 SAVING
# episode: 163/2000000, score: 4.0, average: 3.74 SAVING
# episode: 164/2000000, score: 3.0, average: 3.76 SAVING
# episode: 165/2000000, score: 6.0, average: 3.8 SAVING
# episode: 166/2000000, score: 6.0, average: 3.88 SAVING
# episode: 167/2000000, score: 4.0, average: 3.9 SAVING
# episode: 168/2000000, score: 3.0, average: 3.88
# episode: 169/2000000, score: 4.0, average: 3.9 SAVING
# episode: 170/2000000, score: 5.0, average: 3.92 SAVING
# episode: 171/2000000, score: 4.0, average: 3.94 SAVING
# episode: 172/2000000, score: 5.0, average: 3.98 SAVING
# episode: 173/2000000, score: 2.0, average: 3.96
# episode: 174/2000000, score: 4.0, average: 3.92
# episode: 175/2000000, score: 5.0, average: 3.94
# episode: 176/2000000, score: 7.0, average: 4.02 SAVING
# episode: 177/2000000, score: 8.0, average: 4.14 SAVING
# episode: 178/2000000, score: 4.0, average: 4.12
# episode: 179/2000000, score: 4.0, average: 4.14 SAVING
# episode: 180/2000000, score: 2.0, average: 4.1
# episode: 181/2000000, score: 5.0, average: 4.18 SAVING
# episode: 182/2000000, score: 4.0, average: 4.2 SAVING
# episode: 183/2000000, score: 3.0, average: 4.24 SAVING
# episode: 184/2000000, score: 2.0, average: 4.24 SAVING
# episode: 185/2000000, score: 5.0, average: 4.28 SAVING
# episode: 186/2000000, score: 4.0, average: 4.18
# episode: 187/2000000, score: 5.0, average: 4.22
# episode: 188/2000000, score: 6.0, average: 4.28 SAVING
# episode: 189/2000000, score: 3.0, average: 4.26
# episode: 190/2000000, score: 5.0, average: 4.26
# episode: 191/2000000, score: 7.0, average: 4.32 SAVING
# episode: 192/2000000, score: 4.0, average: 4.36 SAVING
# episode: 193/2000000, score: 7.0, average: 4.38 SAVING
# episode: 194/2000000, score: 3.0, average: 4.34
# episode: 195/2000000, score: 3.0, average: 4.32
# episode: 196/2000000, score: 4.0, average: 4.36
# episode: 197/2000000, score: 3.0, average: 4.34
# episode: 198/2000000, score: 3.0, average: 4.34
# episode: 199/2000000, score: 5.0, average: 4.36
# episode: 200/2000000, score: 7.0, average: 4.4 SAVING
# episode: 201/2000000, score: 4.0, average: 4.4 SAVING
# episode: 202/2000000, score: 4.0, average: 4.4 SAVING
# episode: 203/2000000, score: 5.0, average: 4.38
# episode: 204/2000000, score: 6.0, average: 4.44 SAVING
# episode: 205/2000000, score: 4.0, average: 4.42
# episode: 206/2000000, score: 4.0, average: 4.42
# episode: 207/2000000, score: 6.0, average: 4.46 SAVING
# episode: 208/2000000, score: 4.0, average: 4.48 SAVING
# episode: 209/2000000, score: 4.0, average: 4.5 SAVING
# episode: 210/2000000, score: 5.0, average: 4.5 SAVING
# episode: 211/2000000, score: 3.0, average: 4.48
# episode: 212/2000000, score: 6.0, average: 4.46
# episode: 213/2000000, score: 4.0, average: 4.46
# episode: 214/2000000, score: 5.0, average: 4.5 SAVING
# episode: 215/2000000, score: 4.0, average: 4.46
# episode: 216/2000000, score: 5.0, average: 4.44
# episode: 217/2000000, score: 4.0, average: 4.44
# episode: 218/2000000, score: 6.0, average: 4.5 SAVING
# episode: 219/2000000, score: 5.0, average: 4.52 SAVING
# episode: 220/2000000, score: 6.0, average: 4.54 SAVING
# episode: 221/2000000, score: 5.0, average: 4.56 SAVING
# episode: 222/2000000, score: 5.0, average: 4.56 SAVING
# episode: 223/2000000, score: 6.0, average: 4.64 SAVING
# episode: 224/2000000, score: 5.0, average: 4.66 SAVING
# episode: 225/2000000, score: 5.0, average: 4.66 SAVING
# episode: 226/2000000, score: 5.0, average: 4.62
# episode: 227/2000000, score: 2.0, average: 4.5
# episode: 228/2000000, score: 7.0, average: 4.56
# episode: 229/2000000, score: 6.0, average: 4.6
# episode: 230/2000000, score: 6.0, average: 4.68 SAVING
# episode: 231/2000000, score: 8.0, average: 4.74 SAVING
# episode: 232/2000000, score: 6.0, average: 4.78 SAVING
# episode: 233/2000000, score: 7.0, average: 4.86 SAVING
# episode: 234/2000000, score: 7.0, average: 4.96 SAVING
# episode: 235/2000000, score: 6.0, average: 4.98 SAVING
# episode: 236/2000000, score: 3.0, average: 4.96
# episode: 237/2000000, score: 4.0, average: 4.94
# episode: 238/2000000, score: 7.0, average: 4.96
# episode: 239/2000000, score: 3.0, average: 4.96
# episode: 240/2000000, score: 7.0, average: 5.0 SAVING
# episode: 241/2000000, score: 5.0, average: 4.96
# episode: 242/2000000, score: 5.0, average: 4.98
# episode: 243/2000000, score: 4.0, average: 4.92
# episode: 244/2000000, score: 6.0, average: 4.98
# episode: 245/2000000, score: 5.0, average: 5.02 SAVING
# episode: 246/2000000, score: 1.0, average: 4.96
# episode: 247/2000000, score: 6.0, average: 5.02 SAVING
# episode: 248/2000000, score: 6.0, average: 5.08 SAVING
# episode: 249/2000000, score: 4.0, average: 5.06
# episode: 250/2000000, score: 6.0, average: 5.04
# episode: 251/2000000, score: 6.0, average: 5.08 SAVING
# episode: 252/2000000, score: 6.0, average: 5.12 SAVING
# episode: 253/2000000, score: 3.0, average: 5.08
# episode: 254/2000000, score: 5.0, average: 5.06
# episode: 255/2000000, score: 4.0, average: 5.06
# episode: 256/2000000, score: 5.0, average: 5.08
# episode: 257/2000000, score: 6.0, average: 5.08
# episode: 258/2000000, score: 4.0, average: 5.08
# episode: 259/2000000, score: 6.0, average: 5.12 SAVING
# episode: 260/2000000, score: 2.0, average: 5.06
# episode: 261/2000000, score: 3.0, average: 5.06
# episode: 262/2000000, score: 3.0, average: 5.0
# episode: 263/2000000, score: 5.0, average: 5.02
# episode: 264/2000000, score: 5.0, average: 5.02
# episode: 265/2000000, score: 6.0, average: 5.06
# episode: 266/2000000, score: 4.0, average: 5.04
# episode: 267/2000000, score: 4.0, average: 5.04
# episode: 268/2000000, score: 6.0, average: 5.04
# episode: 269/2000000, score: 5.0, average: 5.04
# episode: 270/2000000, score: 3.0, average: 4.98
# episode: 271/2000000, score: 4.0, average: 4.96
# episode: 272/2000000, score: 4.0, average: 4.94
# episode: 273/2000000, score: 3.0, average: 4.88
# episode: 274/2000000, score: 3.0, average: 4.84
# episode: 275/2000000, score: 3.0, average: 4.8
# episode: 276/2000000, score: 4.0, average: 4.78
# episode: 277/2000000, score: 5.0, average: 4.84
# episode: 278/2000000, score: 6.0, average: 4.82
# episode: 279/2000000, score: 3.0, average: 4.76
# episode: 280/2000000, score: 3.0, average: 4.7
# episode: 281/2000000, score: 4.0, average: 4.62
# episode: 282/2000000, score: 4.0, average: 4.58
# episode: 283/2000000, score: 6.0, average: 4.56
# episode: 284/2000000, score: 4.0, average: 4.5
# episode: 285/2000000, score: 3.0, average: 4.44
# episode: 286/2000000, score: 4.0, average: 4.46
# episode: 287/2000000, score: 5.0, average: 4.48
# episode: 288/2000000, score: 4.0, average: 4.42
# episode: 289/2000000, score: 9.0, average: 4.54
# episode: 290/2000000, score: 5.0, average: 4.5
# episode: 291/2000000, score: 4.0, average: 4.48
# episode: 292/2000000, score: 5.0, average: 4.48
# episode: 293/2000000, score: 6.0, average: 4.52
# episode: 294/2000000, score: 5.0, average: 4.5
# episode: 295/2000000, score: 4.0, average: 4.48
# episode: 296/2000000, score: 3.0, average: 4.52
# episode: 297/2000000, score: 5.0, average: 4.5
# episode: 298/2000000, score: 5.0, average: 4.48
# episode: 299/2000000, score: 3.0, average: 4.46
# episode: 300/2000000, score: 2.0, average: 4.38
# episode: 301/2000000, score: 4.0, average: 4.34
# episode: 302/2000000, score: 3.0, average: 4.28
# episode: 303/2000000, score: 5.0, average: 4.32
# episode: 304/2000000, score: 6.0, average: 4.34
# episode: 305/2000000, score: 5.0, average: 4.36
# episode: 306/2000000, score: 3.0, average: 4.32
# episode: 307/2000000, score: 3.0, average: 4.26
# episode: 308/2000000, score: 3.0, average: 4.24
# episode: 309/2000000, score: 4.0, average: 4.2
# episode: 310/2000000, score: 3.0, average: 4.22
# episode: 311/2000000, score: 2.0, average: 4.2
# episode: 312/2000000, score: 4.0, average: 4.22
# episode: 313/2000000, score: 4.0, average: 4.2
# episode: 314/2000000, score: 2.0, average: 4.14
# episode: 315/2000000, score: 3.0, average: 4.08
# episode: 316/2000000, score: 3.0, average: 4.06
# episode: 317/2000000, score: 3.0, average: 4.04
# episode: 318/2000000, score: 2.0, average: 3.96
# episode: 319/2000000, score: 4.0, average: 3.94
# episode: 320/2000000, score: 2.0, average: 3.92
# episode: 321/2000000, score: 4.0, average: 3.92
# episode: 322/2000000, score: 4.0, average: 3.92
# episode: 323/2000000, score: 3.0, average: 3.92
# episode: 324/2000000, score: 2.0, average: 3.9
# episode: 325/2000000, score: 5.0, average: 3.94
# episode: 326/2000000, score: 4.0, average: 3.94
# episode: 327/2000000, score: 2.0, average: 3.88
# episode: 328/2000000, score: 1.0, average: 3.78
# episode: 329/2000000, score: 5.0, average: 3.82
# episode: 330/2000000, score: 5.0, average: 3.86
# episode: 331/2000000, score: 4.0, average: 3.86
# episode: 332/2000000, score: 2.0, average: 3.82
# episode: 333/2000000, score: 3.0, average: 3.76
# episode: 334/2000000, score: 5.0, average: 3.78
# episode: 335/2000000, score: 5.0, average: 3.82
# episode: 336/2000000, score: 8.0, average: 3.9
# episode: 337/2000000, score: 4.0, average: 3.88
# episode: 338/2000000, score: 3.0, average: 3.86
# episode: 339/2000000, score: 3.0, average: 3.74
# episode: 340/2000000, score: 3.0, average: 3.7
# episode: 341/2000000, score: 3.0, average: 3.68
# episode: 342/2000000, score: 6.0, average: 3.7
# episode: 343/2000000, score: 3.0, average: 3.64
# episode: 344/2000000, score: 5.0, average: 3.64
# episode: 345/2000000, score: 6.0, average: 3.68
# episode: 346/2000000, score: 5.0, average: 3.72
# episode: 347/2000000, score: 6.0, average: 3.74
# episode: 348/2000000, score: 2.0, average: 3.68
# episode: 349/2000000, score: 2.0, average: 3.66
# episode: 350/2000000, score: 4.0, average: 3.7
# episode: 351/2000000, score: 5.0, average: 3.72
# episode: 352/2000000, score: 5.0, average: 3.76
# episode: 353/2000000, score: 4.0, average: 3.74
# episode: 354/2000000, score: 5.0, average: 3.72
# episode: 355/2000000, score: 8.0, average: 3.78
# episode: 356/2000000, score: 2.0, average: 3.76
# episode: 357/2000000, score: 4.0, average: 3.78
# episode: 358/2000000, score: 3.0, average: 3.78
# episode: 359/2000000, score: 6.0, average: 3.82
# episode: 360/2000000, score: 4.0, average: 3.84
# episode: 361/2000000, score: 5.0, average: 3.9
# episode: 362/2000000, score: 3.0, average: 3.88
# episode: 363/2000000, score: 5.0, average: 3.9
# episode: 364/2000000, score: 6.0, average: 3.98
# episode: 365/2000000, score: 6.0, average: 4.04
# episode: 366/2000000, score: 5.0, average: 4.08
# episode: 367/2000000, score: 6.0, average: 4.14
# episode: 368/2000000, score: 1.0, average: 4.12
# episode: 369/2000000, score: 6.0, average: 4.16
# episode: 370/2000000, score: 3.0, average: 4.18
# episode: 371/2000000, score: 3.0, average: 4.16
# episode: 372/2000000, score: 7.0, average: 4.22
# episode: 373/2000000, score: 8.0, average: 4.32
# episode: 374/2000000, score: 6.0, average: 4.4
# episode: 375/2000000, score: 6.0, average: 4.42
# episode: 376/2000000, score: 5.0, average: 4.44
# episode: 377/2000000, score: 6.0, average: 4.52
# episode: 378/2000000, score: 5.0, average: 4.6
# episode: 379/2000000, score: 4.0, average: 4.58
# episode: 380/2000000, score: 6.0, average: 4.6
# episode: 381/2000000, score: 5.0, average: 4.62
# episode: 382/2000000, score: 8.0, average: 4.74
# episode: 383/2000000, score: 7.0, average: 4.82
# episode: 384/2000000, score: 6.0, average: 4.84
# episode: 385/2000000, score: 6.0, average: 4.86
# episode: 386/2000000, score: 5.0, average: 4.8
# episode: 387/2000000, score: 5.0, average: 4.82
# episode: 388/2000000, score: 6.0, average: 4.88
# episode: 389/2000000, score: 8.0, average: 4.98
# episode: 390/2000000, score: 7.0, average: 5.06
# episode: 391/2000000, score: 7.0, average: 5.14 SAVING
# episode: 392/2000000, score: 7.0, average: 5.16 SAVING
# episode: 393/2000000, score: 6.0, average: 5.22 SAVING
# episode: 394/2000000, score: 8.0, average: 5.28 SAVING
# episode: 395/2000000, score: 8.0, average: 5.32 SAVING
# episode: 396/2000000, score: 6.0, average: 5.34 SAVING
# episode: 397/2000000, score: 7.0, average: 5.36 SAVING
# episode: 398/2000000, score: 6.0, average: 5.44 SAVING
# episode: 399/2000000, score: 7.0, average: 5.54 SAVING
# episode: 400/2000000, score: 6.0, average: 5.58 SAVING
# episode: 401/2000000, score: 5.0, average: 5.58 SAVING
# episode: 402/2000000, score: 4.0, average: 5.56
# episode: 403/2000000, score: 3.0, average: 5.54
# episode: 404/2000000, score: 3.0, average: 5.5
# episode: 405/2000000, score: 6.0, average: 5.46
# episode: 406/2000000, score: 4.0, average: 5.5
# episode: 407/2000000, score: 5.0, average: 5.52
# episode: 408/2000000, score: 7.0, average: 5.6 SAVING
# episode: 409/2000000, score: 7.0, average: 5.62 SAVING
# episode: 410/2000000, score: 8.0, average: 5.7 SAVING
# episode: 411/2000000, score: 6.0, average: 5.72 SAVING
# episode: 412/2000000, score: 6.0, average: 5.78 SAVING
# episode: 413/2000000, score: 7.0, average: 5.82 SAVING
# episode: 414/2000000, score: 6.0, average: 5.82 SAVING
# episode: 415/2000000, score: 5.0, average: 5.8
# episode: 416/2000000, score: 4.0, average: 5.78
# episode: 417/2000000, score: 9.0, average: 5.84 SAVING
# episode: 418/2000000, score: 7.0, average: 5.96 SAVING
# episode: 419/2000000, score: 6.0, average: 5.96 SAVING
# episode: 420/2000000, score: 7.0, average: 6.04 SAVING
# episode: 421/2000000, score: 6.0, average: 6.1 SAVING
# episode: 422/2000000, score: 6.0, average: 6.08
# episode: 423/2000000, score: 4.0, average: 6.0
# episode: 424/2000000, score: 8.0, average: 6.04
# episode: 425/2000000, score: 6.0, average: 6.04
# episode: 426/2000000, score: 6.0, average: 6.06
# episode: 427/2000000, score: 5.0, average: 6.04
# episode: 428/2000000, score: 4.0, average: 6.02
# episode: 429/2000000, score: 6.0, average: 6.06
# episode: 430/2000000, score: 4.0, average: 6.02
# episode: 431/2000000, score: 7.0, average: 6.06
# episode: 432/2000000, score: 9.0, average: 6.08
# episode: 433/2000000, score: 4.0, average: 6.02
# episode: 434/2000000, score: 8.0, average: 6.06
# episode: 435/2000000, score: 7.0, average: 6.08
# episode: 436/2000000, score: 8.0, average: 6.14 SAVING
# episode: 437/2000000, score: 7.0, average: 6.18 SAVING
# episode: 438/2000000, score: 5.0, average: 6.16
# episode: 439/2000000, score: 5.0, average: 6.1
# episode: 440/2000000, score: 6.0, average: 6.08
# episode: 441/2000000, score: 11.0, average: 6.16
# episode: 442/2000000, score: 8.0, average: 6.18 SAVING
# episode: 443/2000000, score: 6.0, average: 6.18 SAVING
# episode: 444/2000000, score: 8.0, average: 6.18 SAVING
# episode: 445/2000000, score: 7.0, average: 6.16
# episode: 446/2000000, score: 4.0, average: 6.12
# episode: 447/2000000, score: 4.0, average: 6.06
# episode: 448/2000000, score: 5.0, average: 6.04
# episode: 449/2000000, score: 5.0, average: 6.0
# episode: 450/2000000, score: 6.0, average: 6.0
# episode: 451/2000000, score: 5.0, average: 6.0
# episode: 452/2000000, score: 8.0, average: 6.08
# episode: 453/2000000, score: 7.0, average: 6.16
# episode: 454/2000000, score: 6.0, average: 6.22 SAVING
# episode: 455/2000000, score: 9.0, average: 6.28 SAVING
# episode: 456/2000000, score: 8.0, average: 6.36 SAVING
# episode: 457/2000000, score: 5.0, average: 6.36 SAVING
# episode: 458/2000000, score: 8.0, average: 6.38 SAVING
# episode: 459/2000000, score: 3.0, average: 6.3
# episode: 460/2000000, score: 5.0, average: 6.24
# episode: 461/2000000, score: 7.0, average: 6.26
# episode: 462/2000000, score: 8.0, average: 6.3
# episode: 463/2000000, score: 5.0, average: 6.26
# episode: 464/2000000, score: 7.0, average: 6.28
# episode: 465/2000000, score: 7.0, average: 6.32
# episode: 466/2000000, score: 9.0, average: 6.42 SAVING
# episode: 467/2000000, score: 8.0, average: 6.4
# episode: 468/2000000, score: 4.0, average: 6.34
# episode: 469/2000000, score: 8.0, average: 6.38
# episode: 470/2000000, score: 5.0, average: 6.34
# episode: 471/2000000, score: 2.0, average: 6.26
# episode: 472/2000000, score: 6.0, average: 6.26
# episode: 473/2000000, score: 7.0, average: 6.32
# episode: 474/2000000, score: 7.0, average: 6.3
# episode: 475/2000000, score: 5.0, average: 6.28
# episode: 476/2000000, score: 6.0, average: 6.28
# episode: 477/2000000, score: 6.0, average: 6.3
# episode: 478/2000000, score: 6.0, average: 6.34
# episode: 479/2000000, score: 7.0, average: 6.36
# episode: 480/2000000, score: 7.0, average: 6.42 SAVING
# episode: 481/2000000, score: 6.0, average: 6.4
# episode: 482/2000000, score: 5.0, average: 6.32
# episode: 483/2000000, score: 7.0, average: 6.38
# episode: 484/2000000, score: 9.0, average: 6.4
# episode: 485/2000000, score: 5.0, average: 6.36
# episode: 486/2000000, score: 5.0, average: 6.3
# episode: 487/2000000, score: 5.0, average: 6.26
# episode: 488/2000000, score: 7.0, average: 6.3
# episode: 489/2000000, score: 6.0, average: 6.32
# episode: 490/2000000, score: 9.0, average: 6.38
# episode: 491/2000000, score: 7.0, average: 6.3
# episode: 492/2000000, score: 7.0, average: 6.28
# episode: 493/2000000, score: 5.0, average: 6.26
# episode: 494/2000000, score: 7.0, average: 6.24
# episode: 495/2000000, score: 7.0, average: 6.24
# episode: 496/2000000, score: 6.0, average: 6.28
# episode: 497/2000000, score: 8.0, average: 6.36
# episode: 498/2000000, score: 7.0, average: 6.4
# episode: 499/2000000, score: 8.0, average: 6.46 SAVING
# episode: 500/2000000, score: 7.0, average: 6.48 SAVING
# episode: 501/2000000, score: 8.0, average: 6.54 SAVING
# episode: 502/2000000, score: 8.0, average: 6.54 SAVING
# episode: 503/2000000, score: 8.0, average: 6.56 SAVING
# episode: 504/2000000, score: 5.0, average: 6.54
# episode: 505/2000000, score: 7.0, average: 6.5
# episode: 506/2000000, score: 8.0, average: 6.5
# episode: 507/2000000, score: 6.0, average: 6.52
# episode: 508/2000000, score: 7.0, average: 6.5
# episode: 509/2000000, score: 6.0, average: 6.56 SAVING
# episode: 510/2000000, score: 5.0, average: 6.56 SAVING
# episode: 511/2000000, score: 7.0, average: 6.56 SAVING
# episode: 512/2000000, score: 6.0, average: 6.52
# episode: 513/2000000, score: 6.0, average: 6.54
# episode: 514/2000000, score: 7.0, average: 6.54
# episode: 515/2000000, score: 7.0, average: 6.54
# episode: 516/2000000, score: 7.0, average: 6.5
# episode: 517/2000000, score: 8.0, average: 6.5
# episode: 518/2000000, score: 7.0, average: 6.56 SAVING
# episode: 519/2000000, score: 8.0, average: 6.56 SAVING
# episode: 520/2000000, score: 7.0, average: 6.6 SAVING
# episode: 521/2000000, score: 5.0, average: 6.66 SAVING
# episode: 522/2000000, score: 3.0, average: 6.6
# episode: 523/2000000, score: 8.0, average: 6.62
# episode: 524/2000000, score: 7.0, average: 6.62
# episode: 525/2000000, score: 2.0, average: 6.56
# episode: 526/2000000, score: 6.0, average: 6.56
# episode: 527/2000000, score: 4.0, average: 6.52
# episode: 528/2000000, score: 8.0, average: 6.56
# episode: 529/2000000, score: 8.0, average: 6.58
# episode: 530/2000000, score: 5.0, average: 6.54
# episode: 531/2000000, score: 6.0, average: 6.54
# episode: 532/2000000, score: 8.0, average: 6.6
# episode: 533/2000000, score: 6.0, average: 6.58
# episode: 534/2000000, score: 4.0, average: 6.48
# episode: 535/2000000, score: 7.0, average: 6.52
# episode: 536/2000000, score: 5.0, average: 6.52
# episode: 537/2000000, score: 2.0, average: 6.46
# episode: 538/2000000, score: 8.0, average: 6.48
# episode: 539/2000000, score: 5.0, average: 6.46
# episode: 540/2000000, score: 7.0, average: 6.42
# episode: 541/2000000, score: 2.0, average: 6.32
# episode: 542/2000000, score: 4.0, average: 6.26
# episode: 543/2000000, score: 2.0, average: 6.2
# episode: 544/2000000, score: 7.0, average: 6.2
# episode: 545/2000000, score: 7.0, average: 6.2
# episode: 546/2000000, score: 6.0, average: 6.2
# episode: 547/2000000, score: 7.0, average: 6.18
# episode: 548/2000000, score: 8.0, average: 6.2
# episode: 549/2000000, score: 2.0, average: 6.08
# episode: 550/2000000, score: 4.0, average: 6.02
# episode: 551/2000000, score: 6.0, average: 5.98
# episode: 552/2000000, score: 6.0, average: 5.94
# episode: 553/2000000, score: 6.0, average: 5.9
# episode: 554/2000000, score: 8.0, average: 5.96
# episode: 555/2000000, score: 6.0, average: 5.94
# episode: 556/2000000, score: 6.0, average: 5.9
# episode: 557/2000000, score: 9.0, average: 5.96
# episode: 558/2000000, score: 7.0, average: 5.96
# episode: 559/2000000, score: 5.0, average: 5.94
# episode: 560/2000000, score: 4.0, average: 5.92
# episode: 561/2000000, score: 4.0, average: 5.86
# episode: 562/2000000, score: 8.0, average: 5.9
# episode: 563/2000000, score: 8.0, average: 5.94
# episode: 564/2000000, score: 5.0, average: 5.9
# episode: 565/2000000, score: 5.0, average: 5.86
# episode: 566/2000000, score: 5.0, average: 5.82
# episode: 567/2000000, score: 7.0, average: 5.8
# episode: 568/2000000, score: 5.0, average: 5.76
# episode: 569/2000000, score: 7.0, average: 5.74
# episode: 570/2000000, score: 10.0, average: 5.8
# episode: 571/2000000, score: 7.0, average: 5.84
# episode: 572/2000000, score: 6.0, average: 5.9
# episode: 573/2000000, score: 7.0, average: 5.88
# episode: 574/2000000, score: 9.0, average: 5.92
# episode: 575/2000000, score: 7.0, average: 6.02
# episode: 576/2000000, score: 12.0, average: 6.14
# episode: 577/2000000, score: 9.0, average: 6.24
# episode: 578/2000000, score: 7.0, average: 6.22
# episode: 579/2000000, score: 10.0, average: 6.26
# episode: 580/2000000, score: 6.0, average: 6.28
# episode: 581/2000000, score: 6.0, average: 6.28
# episode: 582/2000000, score: 6.0, average: 6.24
# episode: 583/2000000, score: 8.0, average: 6.28
# episode: 584/2000000, score: 7.0, average: 6.34
# episode: 585/2000000, score: 9.0, average: 6.38
# episode: 586/2000000, score: 7.0, average: 6.42
# episode: 587/2000000, score: 8.0, average: 6.54
# episode: 588/2000000, score: 7.0, average: 6.52
# episode: 589/2000000, score: 7.0, average: 6.56
# episode: 590/2000000, score: 5.0, average: 6.52
# episode: 591/2000000, score: 8.0, average: 6.64
# episode: 592/2000000, score: 8.0, average: 6.72 SAVING
# episode: 593/2000000, score: 8.0, average: 6.84 SAVING
# episode: 594/2000000, score: 7.0, average: 6.84 SAVING
# episode: 595/2000000, score: 6.0, average: 6.82
# episode: 596/2000000, score: 6.0, average: 6.82
# episode: 597/2000000, score: 7.0, average: 6.82
# episode: 598/2000000, score: 7.0, average: 6.8
# episode: 599/2000000, score: 8.0, average: 6.92 SAVING
# episode: 600/2000000, score: 5.0, average: 6.94 SAVING
# episode: 601/2000000, score: 6.0, average: 6.94 SAVING
# episode: 602/2000000, score: 7.0, average: 6.96 SAVING
# episode: 603/2000000, score: 5.0, average: 6.94
# episode: 604/2000000, score: 7.0, average: 6.92
# episode: 605/2000000, score: 7.0, average: 6.94
# episode: 606/2000000, score: 7.0, average: 6.96 SAVING
# episode: 607/2000000, score: 5.0, average: 6.88
# episode: 608/2000000, score: 5.0, average: 6.84
# episode: 609/2000000, score: 7.0, average: 6.88
# episode: 610/2000000, score: 9.0, average: 6.98 SAVING
# episode: 611/2000000, score: 8.0, average: 7.06 SAVING
# episode: 612/2000000, score: 7.0, average: 7.04
# episode: 613/2000000, score: 7.0, average: 7.02
# episode: 614/2000000, score: 7.0, average: 7.06 SAVING
# episode: 615/2000000, score: 5.0, average: 7.06 SAVING
# episode: 616/2000000, score: 5.0, average: 7.06 SAVING
# episode: 617/2000000, score: 3.0, average: 6.98
# episode: 618/2000000, score: 6.0, average: 7.0
# episode: 619/2000000, score: 7.0, average: 7.0
# episode: 620/2000000, score: 6.0, average: 6.92
# episode: 621/2000000, score: 7.0, average: 6.92
# episode: 622/2000000, score: 7.0, average: 6.94
# episode: 623/2000000, score: 7.0, average: 6.94
# episode: 624/2000000, score: 7.0, average: 6.9
# episode: 625/2000000, score: 8.0, average: 6.92
# episode: 626/2000000, score: 7.0, average: 6.82
# episode: 627/2000000, score: 7.0, average: 6.78
# episode: 628/2000000, score: 7.0, average: 6.78
# episode: 629/2000000, score: 7.0, average: 6.72
# episode: 630/2000000, score: 5.0, average: 6.7
# episode: 631/2000000, score: 7.0, average: 6.72
# episode: 632/2000000, score: 8.0, average: 6.76
# episode: 633/2000000, score: 8.0, average: 6.76
# episode: 634/2000000, score: 6.0, average: 6.74
# episode: 635/2000000, score: 7.0, average: 6.7
# episode: 636/2000000, score: 4.0, average: 6.64
# episode: 637/2000000, score: 6.0, average: 6.6
# episode: 638/2000000, score: 6.0, average: 6.58
# episode: 639/2000000, score: 7.0, average: 6.58
# episode: 640/2000000, score: 5.0, average: 6.58
# episode: 641/2000000, score: 6.0, average: 6.54
# episode: 642/2000000, score: 7.0, average: 6.52
# episode: 643/2000000, score: 7.0, average: 6.5
# episode: 644/2000000, score: 7.0, average: 6.5
# episode: 645/2000000, score: 6.0, average: 6.5
# episode: 646/2000000, score: 8.0, average: 6.54
# episode: 647/2000000, score: 8.0, average: 6.56
# episode: 648/2000000, score: 7.0, average: 6.56
# episode: 649/2000000, score: 8.0, average: 6.56
# episode: 650/2000000, score: 7.0, average: 6.6
# episode: 651/2000000, score: 6.0, average: 6.6
# episode: 652/2000000, score: 7.0, average: 6.6
# episode: 653/2000000, score: 8.0, average: 6.66
# episode: 654/2000000, score: 9.0, average: 6.7
# episode: 655/2000000, score: 7.0, average: 6.7
# episode: 656/2000000, score: 8.0, average: 6.72
# episode: 657/2000000, score: 9.0, average: 6.8
# episode: 658/2000000, score: 9.0, average: 6.88
# episode: 659/2000000, score: 9.0, average: 6.92
# episode: 660/2000000, score: 7.0, average: 6.88
# episode: 661/2000000, score: 6.0, average: 6.84
# episode: 662/2000000, score: 7.0, average: 6.84
# episode: 663/2000000, score: 7.0, average: 6.84
# episode: 664/2000000, score: 8.0, average: 6.86
# episode: 665/2000000, score: 7.0, average: 6.9
# episode: 666/2000000, score: 7.0, average: 6.94
# episode: 667/2000000, score: 10.0, average: 7.08 SAVING
# episode: 668/2000000, score: 8.0, average: 7.12 SAVING
# episode: 669/2000000, score: 7.0, average: 7.12 SAVING
# episode: 670/2000000, score: 8.0, average: 7.16 SAVING
# episode: 671/2000000, score: 8.0, average: 7.18 SAVING
# episode: 672/2000000, score: 8.0, average: 7.2 SAVING
# episode: 673/2000000, score: 7.0, average: 7.2 SAVING
# episode: 674/2000000, score: 7.0, average: 7.2 SAVING
# episode: 675/2000000, score: 7.0, average: 7.18
# episode: 676/2000000, score: 8.0, average: 7.2 SAVING
# episode: 677/2000000, score: 7.0, average: 7.2 SAVING
# episode: 678/2000000, score: 7.0, average: 7.2 SAVING
# episode: 679/2000000, score: 7.0, average: 7.2 SAVING
# episode: 680/2000000, score: 11.0, average: 7.32 SAVING
# episode: 681/2000000, score: 7.0, average: 7.32 SAVING
# episode: 682/2000000, score: 10.0, average: 7.36 SAVING
# episode: 683/2000000, score: 8.0, average: 7.36 SAVING
# episode: 684/2000000, score: 8.0, average: 7.4 SAVING
# episode: 685/2000000, score: 8.0, average: 7.42 SAVING
# episode: 686/2000000, score: 8.0, average: 7.5 SAVING
# episode: 687/2000000, score: 7.0, average: 7.52 SAVING
# episode: 688/2000000, score: 6.0, average: 7.52 SAVING
# episode: 689/2000000, score: 9.0, average: 7.56 SAVING
# episode: 690/2000000, score: 8.0, average: 7.62 SAVING
# episode: 691/2000000, score: 6.0, average: 7.62 SAVING
# episode: 692/2000000, score: 9.0, average: 7.66 SAVING
# episode: 693/2000000, score: 10.0, average: 7.72 SAVING
# episode: 694/2000000, score: 10.0, average: 7.78 SAVING
# episode: 695/2000000, score: 9.0, average: 7.84 SAVING
# episode: 696/2000000, score: 9.0, average: 7.86 SAVING
# episode: 697/2000000, score: 10.0, average: 7.9 SAVING
# episode: 698/2000000, score: 8.0, average: 7.92 SAVING
# episode: 699/2000000, score: 9.0, average: 7.94 SAVING
# episode: 700/2000000, score: 9.0, average: 7.98 SAVING
# episode: 701/2000000, score: 6.0, average: 7.98 SAVING
# episode: 702/2000000, score: 9.0, average: 8.02 SAVING
# episode: 703/2000000, score: 8.0, average: 8.02 SAVING
# episode: 704/2000000, score: 7.0, average: 7.98
# episode: 705/2000000, score: 5.0, average: 7.94
# episode: 706/2000000, score: 7.0, average: 7.92
# episode: 707/2000000, score: 9.0, average: 7.92
# episode: 708/2000000, score: 7.0, average: 7.88
# episode: 709/2000000, score: 7.0, average: 7.84
# episode: 710/2000000, score: 9.0, average: 7.88
# episode: 711/2000000, score: 7.0, average: 7.9
# episode: 712/2000000, score: 8.0, average: 7.92
# episode: 713/2000000, score: 9.0, average: 7.96
# episode: 714/2000000, score: 9.0, average: 7.98
# episode: 715/2000000, score: 9.0, average: 8.02 SAVING
# episode: 716/2000000, score: 9.0, average: 8.06 SAVING
# episode: 717/2000000, score: 9.0, average: 8.04
# episode: 718/2000000, score: 8.0, average: 8.04
# episode: 719/2000000, score: 8.0, average: 8.06 SAVING
# episode: 720/2000000, score: 7.0, average: 8.04
# episode: 721/2000000, score: 8.0, average: 8.04
# episode: 722/2000000, score: 9.0, average: 8.06 SAVING
# episode: 723/2000000, score: 8.0, average: 8.08 SAVING
# episode: 724/2000000, score: 9.0, average: 8.12 SAVING
# episode: 725/2000000, score: 7.0, average: 8.12 SAVING
# episode: 726/2000000, score: 9.0, average: 8.14 SAVING
# episode: 727/2000000, score: 6.0, average: 8.12
# episode: 728/2000000, score: 8.0, average: 8.14 SAVING
# episode: 729/2000000, score: 7.0, average: 8.14 SAVING
# episode: 730/2000000, score: 7.0, average: 8.06
# episode: 731/2000000, score: 9.0, average: 8.1
# episode: 732/2000000, score: 9.0, average: 8.08
# episode: 733/2000000, score: 6.0, average: 8.04
# episode: 734/2000000, score: 6.0, average: 8.0
# episode: 735/2000000, score: 9.0, average: 8.02
# episode: 736/2000000, score: 9.0, average: 8.04
# episode: 737/2000000, score: 8.0, average: 8.06
# episode: 738/2000000, score: 6.0, average: 8.06
# episode: 739/2000000, score: 8.0, average: 8.04
# episode: 740/2000000, score: 8.0, average: 8.04
# episode: 741/2000000, score: 8.0, average: 8.08
# episode: 742/2000000, score: 7.0, average: 8.04
# episode: 743/2000000, score: 8.0, average: 8.0
# episode: 744/2000000, score: 8.0, average: 7.96
# episode: 745/2000000, score: 9.0, average: 7.96
# episode: 746/2000000, score: 7.0, average: 7.92
# episode: 747/2000000, score: 9.0, average: 7.9
# episode: 748/2000000, score: 9.0, average: 7.92
# episode: 749/2000000, score: 7.0, average: 7.88
# episode: 750/2000000, score: 8.0, average: 7.86
# episode: 751/2000000, score: 7.0, average: 7.88
# episode: 752/2000000, score: 9.0, average: 7.88
# episode: 753/2000000, score: 9.0, average: 7.9
# episode: 754/2000000, score: 10.0, average: 7.96
# episode: 755/2000000, score: 8.0, average: 8.02
# episode: 756/2000000, score: 9.0, average: 8.06
# episode: 757/2000000, score: 9.0, average: 8.06
# episode: 758/2000000, score: 9.0, average: 8.1
# episode: 759/2000000, score: 6.0, average: 8.08
# episode: 760/2000000, score: 5.0, average: 8.0
# episode: 761/2000000, score: 10.0, average: 8.06
# episode: 762/2000000, score: 9.0, average: 8.08
# episode: 763/2000000, score: 9.0, average: 8.08
# episode: 764/2000000, score: 8.0, average: 8.06
# episode: 765/2000000, score: 9.0, average: 8.06
# episode: 766/2000000, score: 9.0, average: 8.06
# episode: 767/2000000, score: 8.0, average: 8.04
# episode: 768/2000000, score: 9.0, average: 8.06
# episode: 769/2000000, score: 8.0, average: 8.06
# episode: 770/2000000, score: 8.0, average: 8.08
# episode: 771/2000000, score: 9.0, average: 8.1
# episode: 772/2000000, score: 8.0, average: 8.08
# episode: 773/2000000, score: 9.0, average: 8.1
# episode: 774/2000000, score: 9.0, average: 8.1
# episode: 775/2000000, score: 8.0, average: 8.12
# episode: 776/2000000, score: 8.0, average: 8.1
# episode: 777/2000000, score: 6.0, average: 8.1
# episode: 778/2000000, score: 9.0, average: 8.12
# episode: 779/2000000, score: 10.0, average: 8.18 SAVING
# episode: 780/2000000, score: 8.0, average: 8.2 SAVING
# episode: 781/2000000, score: 8.0, average: 8.18
# episode: 782/2000000, score: 10.0, average: 8.2 SAVING
# episode: 783/2000000, score: 9.0, average: 8.26 SAVING
# episode: 784/2000000, score: 11.0, average: 8.36 SAVING
# episode: 785/2000000, score: 10.0, average: 8.38 SAVING
# episode: 786/2000000, score: 10.0, average: 8.4 SAVING
# episode: 787/2000000, score: 8.0, average: 8.4 SAVING
# episode: 788/2000000, score: 8.0, average: 8.44 SAVING
# episode: 789/2000000, score: 8.0, average: 8.44 SAVING
# episode: 790/2000000, score: 8.0, average: 8.44 SAVING
# episode: 791/2000000, score: 7.0, average: 8.42
# episode: 792/2000000, score: 9.0, average: 8.46 SAVING
# episode: 793/2000000, score: 8.0, average: 8.46 SAVING
# episode: 794/2000000, score: 8.0, average: 8.46 SAVING
# episode: 795/2000000, score: 8.0, average: 8.44
# episode: 796/2000000, score: 8.0, average: 8.46 SAVING
# episode: 797/2000000, score: 9.0, average: 8.46 SAVING
# episode: 798/2000000, score: 9.0, average: 8.46 SAVING
# episode: 799/2000000, score: 8.0, average: 8.48 SAVING
# episode: 800/2000000, score: 7.0, average: 8.46
# episode: 801/2000000, score: 8.0, average: 8.48 SAVING
# episode: 802/2000000, score: 8.0, average: 8.46
# episode: 803/2000000, score: 9.0, average: 8.46
# episode: 804/2000000, score: 6.0, average: 8.38
# episode: 805/2000000, score: 9.0, average: 8.4
# episode: 806/2000000, score: 10.0, average: 8.42
# episode: 807/2000000, score: 9.0, average: 8.42
# episode: 808/2000000, score: 10.0, average: 8.44
# episode: 809/2000000, score: 10.0, average: 8.52 SAVING
# episode: 810/2000000, score: 8.0, average: 8.58 SAVING
# episode: 811/2000000, score: 7.0, average: 8.52
# episode: 812/2000000, score: 9.0, average: 8.52
# episode: 813/2000000, score: 9.0, average: 8.52
# episode: 814/2000000, score: 10.0, average: 8.56
# episode: 815/2000000, score: 9.0, average: 8.56
# episode: 816/2000000, score: 6.0, average: 8.5
# episode: 817/2000000, score: 8.0, average: 8.5
# episode: 818/2000000, score: 9.0, average: 8.5
# episode: 819/2000000, score: 9.0, average: 8.52
# episode: 820/2000000, score: 10.0, average: 8.56
# episode: 821/2000000, score: 8.0, average: 8.54
# episode: 822/2000000, score: 7.0, average: 8.52
# episode: 823/2000000, score: 7.0, average: 8.48
# episode: 824/2000000, score: 7.0, average: 8.44
# episode: 825/2000000, score: 9.0, average: 8.46
# episode: 826/2000000, score: 6.0, average: 8.42
# episode: 827/2000000, score: 9.0, average: 8.48
# episode: 828/2000000, score: 6.0, average: 8.42
# episode: 829/2000000, score: 6.0, average: 8.34
# episode: 830/2000000, score: 8.0, average: 8.34
# episode: 831/2000000, score: 7.0, average: 8.32
# episode: 832/2000000, score: 8.0, average: 8.28
# episode: 833/2000000, score: 8.0, average: 8.26
# episode: 834/2000000, score: 9.0, average: 8.22
# episode: 835/2000000, score: 9.0, average: 8.2
# episode: 836/2000000, score: 7.0, average: 8.14
# episode: 837/2000000, score: 7.0, average: 8.12
# episode: 838/2000000, score: 9.0, average: 8.14
# episode: 839/2000000, score: 8.0, average: 8.14
# episode: 840/2000000, score: 7.0, average: 8.12
# episode: 841/2000000, score: 6.0, average: 8.1
# episode: 842/2000000, score: 10.0, average: 8.12
# episode: 843/2000000, score: 10.0, average: 8.16
# episode: 844/2000000, score: 6.0, average: 8.12
# episode: 845/2000000, score: 6.0, average: 8.08
# episode: 846/2000000, score: 7.0, average: 8.06
# episode: 847/2000000, score: 8.0, average: 8.04
# episode: 848/2000000, score: 9.0, average: 8.04
# episode: 849/2000000, score: 8.0, average: 8.04
# episode: 850/2000000, score: 8.0, average: 8.06
# episode: 851/2000000, score: 7.0, average: 8.04
# episode: 852/2000000, score: 7.0, average: 8.02
# episode: 853/2000000, score: 6.0, average: 7.96
# episode: 854/2000000, score: 8.0, average: 8.0
# episode: 855/2000000, score: 8.0, average: 7.98
# episode: 856/2000000, score: 9.0, average: 7.96
# episode: 857/2000000, score: 6.0, average: 7.9
# episode: 858/2000000, score: 7.0, average: 7.84
# episode: 859/2000000, score: 7.0, average: 7.78
# episode: 860/2000000, score: 7.0, average: 7.76
# episode: 861/2000000, score: 8.0, average: 7.78
# episode: 862/2000000, score: 9.0, average: 7.78
# episode: 863/2000000, score: 9.0, average: 7.78
# episode: 864/2000000, score: 8.0, average: 7.74
# episode: 865/2000000, score: 7.0, average: 7.7
# episode: 866/2000000, score: 9.0, average: 7.76
# episode: 867/2000000, score: 8.0, average: 7.76
# episode: 868/2000000, score: 6.0, average: 7.7
# episode: 869/2000000, score: 7.0, average: 7.66
# episode: 870/2000000, score: 6.0, average: 7.58
# episode: 871/2000000, score: 8.0, average: 7.58
# episode: 872/2000000, score: 9.0, average: 7.62
# episode: 873/2000000, score: 7.0, average: 7.62
# episode: 874/2000000, score: 9.0, average: 7.66
# episode: 875/2000000, score: 7.0, average: 7.62
# episode: 876/2000000, score: 9.0, average: 7.68
# episode: 877/2000000, score: 7.0, average: 7.64
# episode: 878/2000000, score: 9.0, average: 7.7
# episode: 879/2000000, score: 10.0, average: 7.78
# episode: 880/2000000, score: 8.0, average: 7.78
# episode: 881/2000000, score: 10.0, average: 7.84
# episode: 882/2000000, score: 10.0, average: 7.88
# episode: 883/2000000, score: 5.0, average: 7.82
# episode: 884/2000000, score: 9.0, average: 7.82
# episode: 885/2000000, score: 9.0, average: 7.82
# episode: 886/2000000, score: 8.0, average: 7.84
# episode: 887/2000000, score: 8.0, average: 7.86
# episode: 888/2000000, score: 7.0, average: 7.82
# episode: 889/2000000, score: 10.0, average: 7.86
# episode: 890/2000000, score: 9.0, average: 7.9
# episode: 891/2000000, score: 9.0, average: 7.96
# episode: 892/2000000, score: 9.0, average: 7.94
# episode: 893/2000000, score: 6.0, average: 7.86
# episode: 894/2000000, score: 8.0, average: 7.9
# episode: 895/2000000, score: 7.0, average: 7.92
# episode: 896/2000000, score: 8.0, average: 7.94
# episode: 897/2000000, score: 9.0, average: 7.96
# episode: 898/2000000, score: 8.0, average: 7.94
# episode: 899/2000000, score: 9.0, average: 7.96
# episode: 900/2000000, score: 8.0, average: 7.96
# episode: 901/2000000, score: 6.0, average: 7.94
# episode: 902/2000000, score: 8.0, average: 7.96
# episode: 903/2000000, score: 9.0, average: 8.02
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 262
#     260 env_name = 'PongDeterministic-v4'
#     261 agent = A3CAgent(env_name)
# --> 262 agent.train()
#
# Cell In[1], line 219, in A3CAgent.train(self)
#     216     score += reward
#     217     state = next_state
# --> 219 self.replay(states, actions, rewards)
#     220 states, actions, rewards = [], [], []
#     222 average = self.PlotModel(score, self.episode)
#
# Cell In[1], line 163, in A3CAgent.replay(self, states, actions, rewards)
#     160     critic_loss = tf.cast(critic_loss, 'float32')
#     161     total_loss = actor_loss + critic_loss
# --> 163 grads = tape.gradient(total_loss, self.ActorCritic.trainable_variables)
#     164 self.optimizer.apply_gradients(zip(grads, self.ActorCritic.trainable_variables))
#
# File /media/kimbring2/NewHDD/godot_env/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py:1065, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1059   output_gradients = (
#    1060       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1061           output_gradients))
#    1062   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1063                       for x in output_gradients]
# -> 1065 flat_grad = imperative_grad.imperative_grad(
#    1066     self._tape,
#    1067     flat_targets,
#    1068     flat_sources,
#    1069     output_gradients=output_gradients,
#    1070     sources_raw=flat_sources_raw,
#    1071     unconnected_gradients=unconnected_gradients)
#    1073 if not self._persistent:
#    1074   # Keep track of watched variables before setting tape to None
#    1075   self._watched_variables = self._tape.watched_variables()
#
# File /media/kimbring2/NewHDD/godot_env/lib/python3.9/site-packages/tensorflow/python/eager/imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File /media/kimbring2/NewHDD/godot_env/lib/python3.9/site-packages/tensorflow/python/eager/backprop.py:117, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     108   def _get_control_flow_context(self):
#     109     raise NotImplementedError(
#     110         "tf.GradientTape.gradients() does not support graph control flow "
#     111         "operations like tf.cond or tf.while at this time. Use tf.gradients() "
#     112         "instead. If you need this feature, please file a feature request at "
#     113         "https://github.com/tensorflow/tensorflow/issues/new"
#     114     )
# --> 117 def _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs,
#     118                        out_grads, skip_input_indices, forward_pass_name_scope):
#     119   """Calls the gradient function of the op.
#     120
#     121   Args:
#    (...)
#     133     The gradients with respect to the inputs of the function, as a list.
#     134   """
#     135   mock_op = _MockOp(attr_tuple, inputs, outputs, op_name, skip_input_indices)
#
# KeyboardInterrupt:
